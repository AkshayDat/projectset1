# %%
#importing libraries for Visualizing and finding insights of the data
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
#Reading the data
mushroom_df=pd.read_csv('mushrooms.csv')

# %% [markdown]
# # Finding the insights from the dataset what it consist of

# %%
mushroom_df.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %%
mushroom_df.tail()
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 8119            c         b          y  ...                        s
# 8120            c         b          y  ...                        s
# 8121            c         b          n  ...                        s
# 8122            c         n          b  ...                        k
# 8123            c         b          y  ...                        s
#
#      stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# ...

# %%
mushroom_df.shape
#counting the numbers of rows and columns
# Out:
# (8124, 23)

# %% [markdown]
# # Changing the categorical column 'values' to numeric 'values' using 'LABEL ENCODER'

# %%
collist=mushroom_df.columns.values
for i in range(0,len(collist)):
    a=mushroom_df[collist[i]].unique()
    print(collist[i],"    \t\t",a)
# Out:
# class     		 ['p' 'e']
# cap-shape     		 ['x' 'b' 's' 'f' 'k' 'c']
# cap-surface     		 ['s' 'y' 'f' 'g']
# cap-color     		 ['n' 'y' 'w' 'g' 'e' 'p' 'b' 'u' 'c' 'r']
# bruises     		 ['t' 'f']
# odor     		 ['p' 'a' 'l' 'n' 'f' 'c' 'y' 's' 'm']
# gill-attachment     		 ['f' 'a']
# gill-spacing     		 ['c' 'w']
# gill-size     		 ['n' 'b']
# gill-color     		 ['k' 'n' 'g' 'p' 'w' 'h' 'u' 'e' 'b' 'r' 'y' 'o']
# stalk-shape     		 ['e' 't']
# stalk-root     		 ['e' 'c' 'b' 'r' '?']
# stalk-surface-above-ring     		 ['s' 'f' 'k' 'y']
# stalk-surface-below-ring     		 ['s' 'f' 'y' 'k']
# stalk-color-above-ring     		 ['w' 'g' 'p' 'n' 'b' 'e' 'o' 'c' 'y']
# stalk-color-below-ring     		 ['w' 'p' 'g' 'b' 'n' 'e' 'y' 'o' 'c']
# veil-type     		 ['p']
# veil-color     		 ['w' 'n' 'o' 'y']
# ring-number     		 ['o' 't' 'n']
# ring-type     		 ['p' 'e' 'l' 'f' 'n']
# spore-print-color     		 ['k' 'n' 'u' 'h' 'w' 'r' 'o' 'y' 'b']
# population     		 ['s' 'n' 'a' 'v' 'y' 'c']
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb=LabelEncoder()
for i in range(0,len(collist)):
    lb.fit(mushroom_df[collist[i]])
    mushroom_df[collist[i]]=lb.fit_transform(mushroom_df[collist[i]])

# %%
for i in range(0,len(collist)):
    a=mushroom_df[collist[i]].unique()
    print(collist[i],"    \t\t",a)
# Out:
# class     		 [1 0]
# cap-shape     		 [5 0 4 2 3 1]
# cap-surface     		 [2 3 0 1]
# cap-color     		 [4 9 8 3 2 5 0 7 1 6]
# bruises     		 [1 0]
# odor     		 [6 0 3 5 2 1 8 7 4]
# gill-attachment     		 [1 0]
# gill-spacing     		 [0 1]
# gill-size     		 [1 0]
# gill-color     		 [ 4  5  2  7 10  3  9  1  0  8 11  6]
# stalk-shape     		 [0 1]
# stalk-root     		 [3 2 1 4 0]
# stalk-surface-above-ring     		 [2 0 1 3]
# stalk-surface-below-ring     		 [2 0 3 1]
# stalk-color-above-ring     		 [7 3 6 4 0 2 5 1 8]
# stalk-color-below-ring     		 [7 6 3 0 4 2 8 5 1]
# veil-type     		 [0]
# veil-color     		 [2 0 1 3]
# ring-number     		 [1 2 0]
# ring-type     		 [4 0 2 1 3]
# spore-print-color     		 [2 3 6 1 7 5 4 8 0]
# population     		 [3 2 0 4 5 1]
# habitat     		 [5 1 3 0 4 6 2]

# %%
mushroom_df.head()
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0      1          5            2          4        1     6                1
# 1      0          5            2          9        1     0                1
# 2      0          0            2          8        1     3                1
# 3      1          5            3          8        1     6                1
# 4      0          5            2          3        0     5                1
#
#    gill-spacing  gill-size  gill-color  ...  stalk-surface-below-ring  \
# 0             0          1           4  ...                         2
# 1             0          0           4  ...                         2
# 2             0          0           5  ...                         2
# 3             0          1           5  ...                         2
# 4             1          0           4  ...                         2
#
#    stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# ...

# %%
mushroom_df.info()
#getting the information about the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   int32
#  1   cap-shape                 8124 non-null   int32
#  2   cap-surface               8124 non-null   int32
#  3   cap-color                 8124 non-null   int32
#  4   bruises                   8124 non-null   int32
#  5   odor                      8124 non-null   int32
#  6   gill-attachment           8124 non-null   int32
#  7   gill-spacing              8124 non-null   int32
#  8   gill-size                 8124 non-null   int32
#  9   gill-color                8124 non-null   int32
#  10  stalk-shape               8124 non-null   int32
#  11  stalk-root                8124 non-null   int32
#  12  stalk-surface-above-ring  8124 non-null   int32
#  13  stalk-surface-below-ring  8124 non-null   int32
# ...

# %%
#checking wether the dataset consist of null or nan values 
sns.heatmap(mushroom_df.isnull())

# %%
mushroom_df.isnull().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
#we can say that donot exits any null or nan value

# %% [markdown]
# # Bivariate Analysis

# %%
sns.countplot(x='class',data=mushroom_df)

# %%
sns.countplot(x='class',hue='cap-shape',data=mushroom_df)

# %%
sns.countplot(x='class',hue='odor',data=mushroom_df)

# %%
sns.barplot(x='class',y='habitat', data= mushroom_df)

# %%
sns.distplot(mushroom_df)

# %%
sns.countplot(x='class',hue='gill-size',data=mushroom_df)

# %%
sns.barplot(x=mushroom_df['class'],y=mushroom_df['bruises'])

# %%
#sns.pairplot(mushroom_df)

# %% [markdown]
# # Univariate Analysis

# %%
collist=mushroom_df.columns.values
ncol=23
nrows=10
plt.figure(figsize=(20,45))
for i in range (1,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(mushroom_df[collist[i]],color='red',orient='v')

# %%
sns.distplot(mushroom_df['habitat'])

# %%
sns.distplot(mushroom_df['cap-shape'])

# %%
sns.distplot(mushroom_df['bruises'])

# %%
sns.distplot(mushroom_df['odor'])

# %%
sns.scatterplot(mushroom_df['class'],mushroom_df['odor'])

# %%
#checking the skewness
mushroom_df.skew()
# Out:
# class                       0.071946
# cap-shape                  -0.247052
# cap-surface                -0.590859
# cap-color                   0.706965
# bruises                     0.342750
# odor                       -0.080790
# gill-attachment            -5.977076
# gill-spacing                1.840088
# gill-size                   0.825797
# gill-color                  0.061410
# stalk-shape                -0.271345
# stalk-root                  0.947852
# stalk-surface-above-ring   -1.098739
# stalk-surface-below-ring   -0.757703
# stalk-color-above-ring     -1.835434
# stalk-color-below-ring     -1.791593
# veil-type                   0.000000
# veil-color                 -6.946944
# ring-number                 2.701657
# ring-type                  -0.290018
# spore-print-color           0.548426
# population                 -1.413096
# habitat                     0.985548
# dtype: float64

# %% [markdown]
# # STATISTICAL ANALYSIS

# %%
mushroom_df.describe()
# Out:
#              class    cap-shape  cap-surface    cap-color      bruises  \
# count  8124.000000  8124.000000  8124.000000  8124.000000  8124.000000
# mean      0.482029     3.348104     1.827671     4.504677     0.415559
# std       0.499708     1.604329     1.229873     2.545821     0.492848
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     2.000000     0.000000     3.000000     0.000000
# 50%       0.000000     3.000000     2.000000     4.000000     0.000000
# 75%       1.000000     5.000000     3.000000     8.000000     1.000000
# max       1.000000     5.000000     3.000000     9.000000     1.000000
#
#               odor  gill-attachment  gill-spacing    gill-size   gill-color  \
# count  8124.000000      8124.000000   8124.000000  8124.000000  8124.000000
# mean      4.144756         0.974151      0.161497     0.309207     4.810684
# std       2.103729         0.158695      0.368011     0.462195     3.540359
# ...

# %%
mushroom_cor=mushroom_df.corr()

# %%
mushroom_cor
# Out:
#                              class  cap-shape  cap-surface  cap-color  \
# class                     1.000000   0.052951     0.178446  -0.031384
# cap-shape                 0.052951   1.000000    -0.050454  -0.048203
# cap-surface               0.178446  -0.050454     1.000000  -0.019402
# cap-color                -0.031384  -0.048203    -0.019402   1.000000
# bruises                  -0.501530  -0.035374     0.070228  -0.000764
# odor                     -0.093552  -0.021935     0.045233  -0.387121
# gill-attachment           0.129200   0.078865    -0.034180   0.041436
# gill-spacing             -0.348387   0.013196    -0.282306   0.144259
# gill-size                 0.540024   0.054050     0.208100  -0.169464
# gill-color               -0.530566  -0.006039    -0.161017   0.084659
# stalk-shape              -0.102019   0.063794    -0.014123  -0.456496
# stalk-root               -0.379361   0.030191    -0.126245   0.321274
# ...

# %%
plt.figure(figsize=(15,10))
sns.heatmap(mushroom_cor,cmap='RdGy_r',annot=True)

# %% [markdown]
# # Removing Outliers and skewness from the dataset

# %%
from scipy.stats import zscore
z=np.abs(zscore(mushroom_df))
z
# Out:
# array([[1.0366127 , 1.02971224, 0.14012794, ..., 0.67019486, 0.5143892 ,
#         2.03002809],
#        [0.96468045, 1.02971224, 0.14012794, ..., 0.2504706 , 1.31310821,
#         0.29572966],
#        [0.96468045, 2.08704716, 0.14012794, ..., 0.2504706 , 1.31310821,
#         0.86714922],
#        ...,
#        [0.96468045, 0.8403434 , 0.14012794, ..., 1.50964337, 2.11182722,
#         0.28570978],
#        [1.0366127 , 0.21699152, 0.95327039, ..., 1.42842641, 0.28432981,
#         0.28570978],
#        [0.96468045, 1.02971224, 0.14012794, ..., 0.16925365, 2.11182722,
#         0.28570978]])

# %%
#removing the outliers

# %%
threshold=3

# %%
#printing all the values which are greater than the threshold value
print(np.where(z>3))
# Out:
# (array([1816, 2128, 2128, ..., 8121, 8123, 8123], dtype=int64), array([15, 14, 15, ..., 17,  6, 17], dtype=int64))

# %%
z[1816][15]#checking wether the result is correct or not
# Out:
# 3.0383605317184252

# %%
z[2128][14]#checking wether the result is correct or not
# Out:
# 3.058610708783329

# %%
mushroom_new=mushroom_df[(z<3).all(axis=1)]#removing the outliers

# %%
mushroom_new.shape
# Out:
# (0, 23)

# %%
mushroom_df.shape
# Out:
# (8124, 23)

# %% [raw]
# # Sometimes, you cannot remove the outliers as one column affects the whole dataset, Therefore using the dataset with outliers

# %%
x=mushroom_df.iloc[:,1:]

# %%
x.head()
# Out:
#    cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0          5            2          4        1     6                1
# 1          5            2          9        1     0                1
# 2          0            2          8        1     3                1
# 3          5            3          8        1     6                1
# 4          5            2          3        0     5                1
#
#    gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# 0             0          1           4            0  ...
# 1             0          0           4            0  ...
# 2             0          0           5            0  ...
# 3             0          1           5            0  ...
# 4             1          0           4            1  ...
#
#    stalk-surface-below-ring  stalk-color-above-ring  stalk-color-below-ring  \
# 0                         2                       7                       7
# ...

# %%
y=mushroom_df.iloc[:,0:1]

# %%
y.head()
# Out:
#    class
# 0      1
# 1      0
# 2      0
# 3      1
# 4      0

# %%
#Scaling the data in x
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
df_x=sc.fit_transform(x)

# %%
x=df_x
print(x)
# Out:
# [[ 1.02971224  0.14012794 -0.19824983 ... -0.67019486 -0.5143892
#    2.03002809]
#  [ 1.02971224  0.14012794  1.76587407 ... -0.2504706  -1.31310821
#   -0.29572966]
#  [-2.08704716  0.14012794  1.37304929 ... -0.2504706  -1.31310821
#    0.86714922]
#  ...
#  [-0.8403434   0.14012794 -0.19824983 ... -1.50964337 -2.11182722
#    0.28570978]
#  [-0.21699152  0.95327039 -0.19824983 ...  1.42842641  0.28432981
#    0.28570978]
#  [ 1.02971224  0.14012794 -0.19824983 ...  0.16925365 -2.11182722
#    0.28570978]]

# %%
import sklearn
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,roc_auc_score,roc_curve,auc

# %%
#Finding the best random_state

# %%
max_score=0
final_rstate=0

for i in range(42,101):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.10,random_state=i)
    lg=LogisticRegression()
    lg.fit(x_train,y_train)
    t=lg.score(x_train,y_train)
    pred=lg.predict(x_test)
    acc_score=accuracy_score(y_test,pred)
    print("Accuracy SCORE is equal to :",acc_score,"at random state",i)
    if acc_score > max_score:
        max_score=acc_score
        final_rstate=i
        
        
    
    
print("The maximum Accuracy_score is ",max_score, "at random state",final_rstate)
# Out:
# Accuracy SCORE is equal to : 0.9544895448954489 at random state 42
# Accuracy SCORE is equal to : 0.9618696186961869 at random state 43
# Accuracy SCORE is equal to : 0.968019680196802 at random state 44
# Accuracy SCORE is equal to : 0.9606396063960639 at random state 45
# Accuracy SCORE is equal to : 0.9606396063960639 at random state 46
# Accuracy SCORE is equal to : 0.9606396063960639 at random state 47
# Accuracy SCORE is equal to : 0.968019680196802 at random state 48
# Accuracy SCORE is equal to : 0.9520295202952029 at random state 49
# Accuracy SCORE is equal to : 0.942189421894219 at random state 50
# Accuracy SCORE is equal to : 0.9630996309963099 at random state 51
# Accuracy SCORE is equal to : 0.9544895448954489 at random state 52
# Accuracy SCORE is equal to : 0.964329643296433 at random state 53
# Accuracy SCORE is equal to : 0.956949569495695 at random state 54
# Accuracy SCORE is equal to : 0.958179581795818 at random state 55
# ...

# %%
#finalizing the train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.10,random_state=62)
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (7311, 22) (813, 22) (7311, 1) (813, 1)

# %% [raw]
# Finding best parameters using Grid_Search_Cv

# %%
#best parameter for Logistic Regression
from sklearn.model_selection import GridSearchCV
lrg=LogisticRegression()
parameters={'penalty':['l1','l2']}
gd=GridSearchCV(lrg,parameters)
gd.fit(x_train,y_train)
gd.best_params_
# Out:
# {'penalty': 'l2'}

# %%
from sklearn.model_selection import GridSearchCV
svc=SVC()
parameters={'kernel':('linear','rbf'), 'C':[0.1,1]}
gd=GridSearchCV(svc,parameters)
gd.fit(x_train,y_train)
gd.best_params_
# Out:
# {'C': 1, 'kernel': 'rbf'}

# %%
from sklearn.model_selection import GridSearchCV
knn=KNeighborsClassifier()
parameters={'n_neighbors':(1,10)}
gd=GridSearchCV(knn,parameters)
gd.fit(x_train,y_train)
gd.best_params_
# Out:
# {'n_neighbors': 1}

# %%
from sklearn.model_selection import GridSearchCV
dtc=DecisionTreeClassifier()
parameters={'criterion':('gini','entropy')}
gd=GridSearchCV(dtc,parameters)
gd.fit(x_train,y_train)
gd.best_params_
# Out:
# {'criterion': 'gini'}

# %%
Model= []
score= []
cvs=[]
rocscore=[]
model=[LogisticRegression(penalty='l2'),DecisionTreeClassifier(criterion='gini'),SVC(C=1,kernel='rbf'),KNeighborsClassifier(n_neighbors=1),GaussianNB()]
for models in model:
    print("\n")
    Model.append(models)
    models.fit(x_train,y_train)
    print(models)
    prediction=models.predict(x_test)
    print("\n")
    acc_score=accuracy_score(y_test,prediction)
    print("ACCURACY_SCORE =",acc_score)
    score.append(acc_score*100)
    print("\n")
    cv_score=cross_val_score(models,x,y,cv=10, scoring='accuracy').mean()
    print("CROSS_VAL_SCORE =",cv_score)
    cvs.append(cv_score*100)
    print("\n")
    false_positive_rate, true_positive_rate,  thresholds=roc_curve(y_test,prediction)
    roc_auc= auc(false_positive_rate, true_positive_rate)
    print("ROC_AUC_SCORE =",roc_auc)
    rocscore.append(roc_auc*100)
    print("\n")
    print(" \n Classification Report \n ",classification_report(y_test,prediction))
    print("\n")
    cm=confusion_matrix(y_test,prediction)
    print(cm)
    print("\n") 
    plt.figure(figsize=(10,30))
    plt.subplot(911)
    plt.title(models)
    print(sns.heatmap(cm,annot=True))   
    plt.subplot(912)
    plt.title(models)      
    plt.plot(false_positive_rate, true_positive_rate, label= "AUC = %0.2f" % roc_auc)
    plt.plot([0,1],[0,1],'r--') 
    plt.legend(loc='lower right')
    plt.ylabel("True positive rate")
    plt.xlabel("False positive rate")
    print("\n \n \n")
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)
#
#
# ACCURACY_SCORE = 0.9704797047970479
#
#
# CROSS_VAL_SCORE = 0.8875029538472725
#
#
# ROC_AUC_SCORE = 0.9705288985823337
#
#
#
#  Classification Report
#                 precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97       420
#            1       0.97      0.97      0.97       393
#
#     accuracy                           0.97       813
#    macro avg       0.97      0.97      0.97       813
# weighted avg       0.97      0.97      0.97       813
#
#
#
# [[407  13]
#  [ 11 382]]
#
#
# AxesSubplot(0.125,0.808774;0.62x0.0712264)
#
#
#
#
#
#
# ...

# %%
outcome=pd.DataFrame({'Model':['LogisticRegression','DecisionTreeClassifier','SVC','KNeighborsClassifier','GaussianNB'],'Accuracy_Score':[0.97,1.0,1.0,1.0,0.94],'Cross_Val_Sore':[0.88,0.96,0.95,0.96,0.84],'Roc_Auc_Score':[0.97,1.0,1.0,1.0,0.94]})
outcome
# Out:
#                     Model  Accuracy_Score  Cross_Val_Sore  Roc_Auc_Score
# 0      LogisticRegression            0.97            0.88           0.97
# 1  DecisionTreeClassifier            1.00            0.96           1.00
# 2                     SVC            1.00            0.95           1.00
# 3    KNeighborsClassifier            1.00            0.96           1.00
# 4              GaussianNB            0.94            0.84           0.94

# %%
#Hence it is observed that knn is giving a good result, therefore finalizing it

# %%
knn=KNeighborsClassifier(n_neighbors=1)
knn.fit(x_train,y_train)
prediction=knn.predict(x_test)
acc_score=accuracy_score(prediction,y_test)
print("Accuracy Score =", acc_score)
cv_score=cross_val_score(svc,x,y,cv=10,scoring='accuracy').mean()
print("The Cross Val Score =", cv_score)
# Out:
# Accuracy Score = 1.0
# The Cross Val Score = 0.9580437048212846

# %%
from sklearn.externals import joblib
joblib.dump(knn,"knn_mushroom.pkl")
# Out:
# ['knn_mushroom.pkl']
